# %%
import numpy as np
import pandas as pd
z=pd.read_csv('C:/Users/Administrator/Desktop/Customer Purchasing Behaviors.csv')
z
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# ..       ...  ...            ...              ...            ...    ...
# 233      234   40          60000              450            7.2   West
# 234      235   38          59000              430            6.9  North
# 235      236   54          74000              630            9.4  South
# 236      237   32          52000              360            5.8   West
# 237      238   31          51000              340            5.6  North
#
#      purchase_frequency
# 0                    12
# 1                    18
# 2                    22
# ...

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             238 non-null    int64
#  1   age                 238 non-null    int64
#  2   annual_income       238 non-null    int64
#  3   purchase_amount     238 non-null    int64
#  4   loyalty_score       238 non-null    float64
#  5   region              238 non-null    object
#  6   purchase_frequency  238 non-null    int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 13.1+ KB

# %%
z.isnull().sum()
# Out:
# user_id               0
# age                   0
# annual_income         0
# purchase_amount       0
# loyalty_score         0
# region                0
# purchase_frequency    0
# dtype: int64

# %%
z['region'].unique()
# Out:
# array(['North', 'South', 'West', 'East'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()

# %%
#z['region']=l.fit_transform(z['region'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(x=z['age'])
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(x=z['annual_income'])
# Out:
# <Axes: xlabel='annual_income'>

# %%
sns.boxplot(x=z['purchase_amount'])
# Out:
# <Axes: xlabel='purchase_amount'>

# %%
sns.boxplot(x=z['purchase_frequency'])
# Out:
# <Axes: xlabel='purchase_frequency'>

# %%
sns.boxplot(x=z['loyalty_score'])
# Out:
# <Axes: xlabel='loyalty_score'>

# %%
plt.hist(z['age'],bins=20,color='green')
# Out:
# (array([ 2., 16.,  8., 16., 17.,  9., 22.,  3.,  8., 16., 16., 14., 14.,
#          9.,  8.,  8., 22.,  7.,  9., 14.]),
#  array([22.  , 23.65, 25.3 , 26.95, 28.6 , 30.25, 31.9 , 33.55, 35.2 ,
#         36.85, 38.5 , 40.15, 41.8 , 43.45, 45.1 , 46.75, 48.4 , 50.05,
#         51.7 , 53.35, 55.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(z['annual_income'],bins=5,color='green')
# Out:
# (array([16., 34., 51., 69., 68.]),
#  array([30000., 39000., 48000., 57000., 66000., 75000.]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(z['purchase_amount'],bins=10,color='green')
# Out:
# (array([16., 20., 15., 17., 25., 32., 30., 24., 15., 44.]),
#  array([150., 199., 248., 297., 346., 395., 444., 493., 542., 591., 640.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(z['purchase_frequency'],bins=10,color='green')
# Out:
# (array([15.,  5., 31., 17., 23., 33., 47., 23., 29., 15.]),
#  array([10. , 11.8, 13.6, 15.4, 17.2, 19. , 20.8, 22.6, 24.4, 26.2, 28. ]),
#  <BarContainer object of 10 artists>)

# %%
z.groupby(['region']).count()
# Out:
#         user_id  age  annual_income  purchase_amount  loyalty_score  \
# region
# East          6    6              6                6              6
# North        78   78             78               78             78
# South        77   77             77               77             77
# West         77   77             77               77             77
#
#         purchase_frequency
# region
# East                     6
# North                   78
# South                   77
# West                    77

# %%
a=z.groupby(['region']).size().reset_index(name="count").rename(columns={'region':'Region'})
a
# Out:
#   Region  count
# 0   East      6
# 1  North     78
# 2  South     77
# 3   West     77

# %%
plt.figure(figsize=(8,6))
plt.pie(a['count'], labels = a['Region'], autopct='%1.1f%%')
plt.title('Region Distribution')
plt.show()

# %%
z['region']=l.fit_transform(z['region'])

# %%
sns.pairplot(z)

# %%
z.corr()
# Out:
#                      user_id       age  annual_income  purchase_amount  \
# user_id             1.000000  0.067061       0.059031         0.080621
# age                 0.067061  1.000000       0.974833         0.986140
# annual_income       0.059031  0.974833       1.000000         0.984208
# purchase_amount     0.080621  0.986140       0.984208         1.000000
# loyalty_score       0.060819  0.981835       0.984351         0.994147
# region              0.089772  0.443132       0.409226         0.452714
# purchase_frequency  0.070541  0.980532       0.982920         0.993579
#
#                     loyalty_score    region  purchase_frequency
# user_id                  0.060819  0.089772            0.070541
# age                      0.981835  0.443132            0.980532
# annual_income            0.984351  0.409226            0.982920
# purchase_amount          0.994147  0.452714            0.993579
# loyalty_score            1.000000  0.448869            0.986990
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(z.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
sns.lmplot(x='age',y='loyalty_score',data=z)
plt.title("Correlation between age and how loyal the customer is to the store")
# Out:
# Text(0.5, 1.0, 'Correlation between age and how loyal the customer is to the store')

# %%
sns.lmplot(x='annual_income',y='age',data=z)
plt.title("Correlation between a person's age and how much they make")
# Out:
# Text(0.5, 1.0, "Correlation between a person's age and how much they make")

# %%
x=z[['annual_income','age','purchase_frequency','purchase_amount']]
y=z['loyalty_score']
x
# Out:
#      annual_income  age  purchase_frequency  purchase_amount
# 0            45000   25                  12              200
# 1            55000   34                  18              350
# 2            65000   45                  22              500
# 3            30000   22                  10              150
# 4            47000   29                  13              220
# ..             ...  ...                 ...              ...
# 233          60000   40                  20              450
# 234          59000   38                  20              430
# 235          74000   54                  27              630
# 236          52000   32                  18              360
# 237          51000   31                  17              340
#
# [238 rows x 4 columns]

# %%
y
# Out:
# 0      4.5
# 1      7.0
# 2      8.0
# 3      3.0
# 4      4.8
#       ...
# 233    7.2
# 234    6.9
# 235    9.4
# 236    5.8
# 237    5.6
# Name: loyalty_score, Length: 238, dtype: float64

# %%
from sklearn.feature_selection import f_classif
a=f_classif(x,y)
a
# Out:
# (array([3734.28958193, 1588.34875126, 1525.88101801, 2022.73054364]),
#  array([2.75907294e-265, 1.03294974e-227, 5.95558059e-226, 2.50250598e-238]))

# %%
a=pd.Series(a[1])
a.index=x.columns
a
# Out:
# annual_income         2.759073e-265
# age                   1.032950e-227
# purchase_frequency    5.955581e-226
# purchase_amount       2.502506e-238
# dtype: float64

# %%
z
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score  region  \
# 0          1   25          45000              200            4.5       1
# 1          2   34          55000              350            7.0       2
# 2          3   45          65000              500            8.0       3
# 3          4   22          30000              150            3.0       0
# 4          5   29          47000              220            4.8       1
# ..       ...  ...            ...              ...            ...     ...
# 233      234   40          60000              450            7.2       3
# 234      235   38          59000              430            6.9       1
# 235      236   54          74000              630            9.4       2
# 236      237   32          52000              360            5.8       3
# 237      238   31          51000              340            5.6       1
#
#      purchase_frequency
# 0                    12
# 1                    18
# ...

# %%
x=z.drop(columns=['purchase_amount'])
y=z['purchase_amount']
x
# Out:
#      user_id  age  annual_income  loyalty_score  region  purchase_frequency
# 0          1   25          45000            4.5       1                  12
# 1          2   34          55000            7.0       2                  18
# 2          3   45          65000            8.0       3                  22
# 3          4   22          30000            3.0       0                  10
# 4          5   29          47000            4.8       1                  13
# ..       ...  ...            ...            ...     ...                 ...
# 233      234   40          60000            7.2       3                  20
# 234      235   38          59000            6.9       1                  20
# 235      236   54          74000            9.4       2                  27
# 236      237   32          52000            5.8       3                  18
# 237      238   31          51000            5.6       1                  17
#
# [238 rows x 6 columns]

# %%
y
# Out:
# 0      200
# 1      350
# 2      500
# 3      150
# 4      220
#       ...
# 233    450
# 234    430
# 235    630
# 236    360
# 237    340
# Name: purchase_amount, Length: 238, dtype: int64

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.tree import DecisionTreeRegressor

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
decision_tree_regressor=DecisionTreeRegressor(max_depth=2)

# %%
decision_tree_regressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
from sklearn import tree
plt.figure(figsize=(10,10))
tree.plot_tree(decision_tree_regressor,filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[5] <= 19.5\nsquared_error = 18754.349\nsamples = 190\nvalue = 428.421'),
#  Text(0.25, 0.5, 'x[1] <= 29.5\nsquared_error = 6248.734\nsamples = 80\nvalue = 293.875'),
#  Text(0.125, 0.16666666666666666, 'squared_error = 1418.408\nsamples = 37\nvalue = 217.568'),
#  Text(0.375, 0.16666666666666666, 'squared_error = 1083.505\nsamples = 43\nvalue = 359.535'),
#  Text(0.75, 0.5, 'x[2] <= 67000.0\nsquared_error = 5108.835\nsamples = 110\nvalue = 526.273'),
#  Text(0.625, 0.16666666666666666, 'squared_error = 1028.571\nsamples = 63\nvalue = 470.0'),
#  Text(0.875, 0.16666666666666666, 'squared_error = 643.911\nsamples = 47\nvalue = 601.702')]

# %%
pre=decision_tree_regressor.predict(x_test)
print(f"The error rate of the model is {mean_squared_error(y_test,pre)} and the performance is {r2_score(y_test,pre)}")
# Out:
# The error rate of the model is 1182.782303494424 and the performance is 0.9473339615478793

# %%
tree_regressor=DecisionTreeRegressor()

# %%
parameter={    'criterion': ['mse', 'friedman_mse', 'mae'],
    'splitter': ['best', 'random'],
    'max_depth': [1, 2, 3, 4, 5],
    'max_features': ['auto', 'sqrt', 'log2']

}

# %%
model=GridSearchCV(tree_regressor,parameter,cv=5,scoring='neg_mean_squared_error')

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\Administrator\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# C:\Users\Administrator\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# C:\Users\Administrator\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# ...

# %%
pr=model.predict(x_test)
print(f"The error rate of the model is {mean_squared_error(y_test,pr)} and the performance is {r2_score(y_test,pr)}")
# Out:
# The error rate of the model is 79.22483498991403 and the performance is 0.9964723362924737
